# %% [markdown]
# # setup

# %%
import os

if os.getcwd().split('/')[-1] == 'notebooks':
    os.chdir('..')

# %%
import scipy.io as sio
import matplotlib.pyplot as plt
import numpy as np
import math
import tensorflow as tf
import tensorflow_probability as tfp
# import tensorflow_addons as tfa
import pandas as pd
import sys
import sklearn.model_selection

from random import randint
from sklearn.metrics import mean_squared_error
from matplotlib.pyplot import figure
from IPython.display import SVG
from sklearn.linear_model import LinearRegression
# Out:
# 2024-08-27 04:22:34.895367: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
from tensorflow.python.keras import layers, initializers, optimizers
from tensorflow.python.keras.layers import Input, Dense, Activation, ZeroPadding1D, BatchNormalization, Flatten, Conv2D
from tensorflow.python.keras.layers import AveragePooling1D, MaxPooling2D, Dropout, GlobalMaxPooling1D, GlobalAveragePooling1D
from tensorflow.python.keras.layers import LeakyReLU, Reshape
from tensorflow.python.keras.models import Model, model_from_json, load_model
from tensorflow.python.keras.preprocessing import image
from tensorflow.python.keras.utils import layer_utils
from tensorflow.python.keras.utils.data_utils import get_file
from tensorflow.python.keras.applications.imagenet_utils import preprocess_input
from tensorflow.python.keras.utils.vis_utils import model_to_dot
from tensorflow.python.keras.utils.vis_utils import plot_model
from tensorflow.python.keras.utils import np_utils
from tensorflow.python.keras.backend import manual_variable_initialization
from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint

import tensorflow.python.keras.backend as K
K.set_image_data_format('channels_last')

# %% [markdown]
# # utils

# %%
def ricker_wav(f, n, dt, t0):
    T = dt * (np.floor(n / 2))
    t = np.linspace(-T, T, n)
    tau = t - t0
    pi = np.pi
    s = (1-2*tau*tau*f**2*pi**2) * np.exp(-tau**2*pi**2*f**2)
    rw = s
    return rw, t

# %%
freq = 40
src_len = 60
dt = 7e-4
wvlt, tt = ricker_wav(freq, src_len, dt, 0)

plt.plot(tt, wvlt);
plt.xlabel("Time (s)");
plt.ylabel("Amplitude");
plt.title("Source Wavelet");

# %%
def SoftSandNew(Kf, RHOf, Phi, Quartz, Clay, Feldspar, Limestone, Dolomite, Pressure, PhiC, Coordination, Fudge):
    # Uncemented sand rock physics model (modified to implement automatic-differentiation)
    #               INPUTS
    #
    #Kf				Fluid bulk modulus
    #RHOB			Fluid density
    #Phi			Porosity (fraction)
    #Quartz, etc.	Volume mineral content in solid phase (fraction)
    #Pressure		Effective pressure (MPa)
    #PhiC			Critical porosity ~0.4
    #Coordination	Coordination number ~6
    #Fudge			Reduction in shear stiffness -- 1 by default
    #
    #a is the contact radius between two spheres at input pressure

    #Balancing mineralogy
    Dolomite = 1 - (Quartz + Clay + Feldspar + Limestone)
    
    #Constants for clay
    KClay = 21
    GClay = 7
    RHOClay = 2.65

    #Solid-phase elastic moduli
    KsV = Quartz*36.6 + Clay*KClay + Feldspar*75.6 + Limestone*76.8 + Dolomite*94.9
    KsR = 1 / (Quartz/36.6 + Clay/KClay + Feldspar/75.6 + Limestone/76.8 + Dolomite/94.9)
    Ks = 0.5 * (KsV + KsR)
    
    GsV = Quartz*45 + Clay*GClay + Feldspar*25.6 + Limestone*32 + Dolomite*45
    GsR = 1 / (Quartz/45 + Clay/GClay + Feldspar/25.6 + Limestone/32 + Dolomite/45)
    Gs = 0.5 * (GsV + GsR)

    Ms = Ks + (4/3)*Gs
    NUs = 0.5 * (Ms/Gs-2) / (Ms/Gs-1)
    
    #Solid-phase density
    RHOs = Quartz*2.65 + Clay*RHOClay + Feldspar*2.63 + Limestone*2.71 + Dolomite*2.87
    
    #ILLITE
    #RHOs=2.58; Ms=RHOs.*4.32.*4.32; Gs=RHOs.*2.54.*2.54; NUs=0.5*(Ms./Gs-2)./(Ms./Gs-1); Ks=Ms-(4/3)*Gs;
    
    P = Pressure / 1000
    C = Coordination
    
    #================== Dry Rock ====================
    #Effective K and G at PhiC
    #Hertz contact radius (R=1)
    a = tf.pow(((3*3.14*(1-NUs) / (2*C*(1-PhiC)*Gs))*P), (1/3))
    #Normal contact stiffness
    SN = 4*a*Gs / (1-NUs)
    #Shear contact stiffness
    ST = 8*a*Gs / (2-NUs)
    #Shear contact stiffness FUDGED (reduced)
    ST = ST / Fudge
    
    #Bulk modulus
    Khat = C*(1.-PhiC)*SN / (12*3.14)
    #Shear modulus
    Ghat = C*(1.-PhiC)*(SN+1.5*ST) / (20*3.14)
    
    #Effective bulk and shear moduli at porosity Phi<=PhiC
    KDry1 = 1/((Phi/PhiC)/(Khat+4*Ghat/3)+((PhiC-Phi)/PhiC)/(Ks+4*Ghat/3))-4*Ghat/3
    ZZ1 = (Ghat/6)*(9*Khat+8*Ghat)/(Khat+2*Ghat)
    GDry1 = 1/((Phi/PhiC)/(Ghat+ZZ1)+((PhiC-Phi)/PhiC)/(Gs+ZZ1))-ZZ1
    MDry1 = KDry1+(4/3)*GDry1
    NuDry1 = 0.5*(MDry1/GDry1-2)/(MDry1/GDry1-1)
    
    #Effective bulk and shear moduli at porosity Phi>PhiC
    KDry2 = 1/(((1-Phi)/(1-PhiC))/(Khat+4*Ghat/3)+((Phi-PhiC)/(1-PhiC))/(4*Ghat/3))-4*Ghat/3
    ZZ2 = (Ghat/6)*(9*Khat+8*Ghat)/(Khat+2*Ghat)
    GDry2 = 1/(((1-Phi)/(1-PhiC))/(Ghat+ZZ2)+((Phi-PhiC)/(1-PhiC))/(ZZ2))-ZZ2
    MDry2 = KDry2+(4/3)*GDry2
    NuDry2 = 0.5*(MDry2/GDry2-2)/(MDry2/GDry2-1)
    
    MDry = MDry1*(tf.cast((Phi<=PhiC), tf.float64))+MDry2*(tf.cast((Phi>PhiC), tf.float64)) 
    GDry = GDry1*(tf.cast((Phi<=PhiC), tf.float64))+GDry2*(tf.cast((Phi>PhiC), tf.float64))
    NuDry = NuDry1*(tf.cast((Phi<=PhiC), tf.float64))+NuDry2*(tf.cast((Phi>PhiC), tf.float64))
    KDry = MDry-(4/3)*GDry
    
    # ================== Saturated Rock ============
    KSat = Ks*(Phi*KDry-(1+Phi)*Kf*KDry/Ks+Kf)/((1-Phi)*Kf+Phi*Ks-Kf*KDry/Ks)
    MSat = KSat+(4/3)*GDry
    RHOB = (1-Phi)*RHOs+Phi*RHOf
    Vp = tf.pow((MSat/RHOB),0.5)
    Vs = tf.pow((GDry/RHOB),0.5)
    Ip = Vp*RHOB
    PR = 0.5*(MSat/GDry-2)/(MSat/GDry-1)
    
    return Vp, Vs, RHOB

# %%
def RC_fwd_model(vp1, d1, vp2, d2):
    Rpp = (vp2*d2-vp1*d1) / (vp2*d2+vp1*d1)
    return Rpp

# %%
def RC_fwd_model_ia(ia1, ia2):
    Rpp = (ia2-ia1) / (ia2+ia1)
    return Rpp

# %% [markdown]
# # read

# %%
Kg = 0.06
Kw = 2.61
RHOw = 1.01
RHOg = 0.18 
diffP = 16.5 
RHOs = 2.65
PhiC = 0.4 
Coordination = 14 
Fudge = 1
diffDepth = 1

# We have not analyzed the impact of partialsaturations or the presence of clay on the predictions
vclay = tf.cast(0, tf.float64)
sw = tf.cast(1, tf.float64)
# Out:
# 2024-08-27 04:22:43.444982: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2024-08-27 04:22:43.476108: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2024-08-27 04:22:44.128408: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-08-27 04:22:44.128781: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: TITAN V computeCapability: 7.0
# coreClock: 1.455GHz coreCount: 80 deviceMemorySize: 11.78GiB deviceMemoryBandwidth: 607.97GiB/s
# 2024-08-27 04:22:44.128812: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2024-08-27 04:22:44.400641: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2024-08-27 04:22:44.400789: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2024-08-27 04:22:44.497820: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2024-08-27 04:22:44.546192: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2024-08-27 04:22:44.659683: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2024-08-27 04:22:44.741708: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2024-08-27 04:22:44.762324: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2024-08-27 04:22:44.762694: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-08-27 04:22:44.764568: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-08-27 04:22:44.783287: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2024-08-27 04:22:44.802288: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2024-08-27 04:22:44.802657: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-08-27 04:22:44.804315: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: TITAN V computeCapability: 7.0
# coreClock: 1.455GHz coreCount: 80 deviceMemorySize: 11.78GiB deviceMemoryBandwidth: 607.97GiB/s
# 2024-08-27 04:22:44.804402: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2024-08-27 04:22:44.804486: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2024-08-27 04:22:44.804563: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2024-08-27 04:22:44.804639: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2024-08-27 04:22:44.804713: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2024-08-27 04:22:44.804788: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2024-08-27 04:22:44.804863: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2024-08-27 04:22:44.804938: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2024-08-27 04:22:44.805193: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-08-27 04:22:44.806955: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-08-27 04:22:44.808522: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2024-08-27 04:22:44.838361: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2024-08-27 04:22:50.037126: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2024-08-27 04:22:50.037205: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2024-08-27 04:22:50.037233: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2024-08-27 04:22:50.049687: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-08-27 04:22:50.051573: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-08-27 04:22:50.053338: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-08-27 04:22:50.054932: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10908 MB memory) -> physical GPU (device: 0, name: TITAN V, pci bus id: 0000:01:00.0, compute capability: 7.0)

# %%
seis = np.load('seismic_data.npy') ##seismic data
phi_true = np.load('porosity_data.npy') ##porosity data
seis.shape, phi_true.shape
# Out:
# ((2500, 246), (2500, 199))

# %%
phi_max = np.max(phi_true) #can also take 1 or critical porosity (0.4)
phi_min = np.min(phi_true) #can also take 0
phi_max, phi_min
# Out:
# (0.4, 0.11)

# %%
# Normalizing the input and output data  

seis_normalized = (seis - np.min(seis)) / (np.max(seis) - np.min(seis))

#seis_compiled=np.concatenate((seis_normalized[:,0,:],seis_normalized[:,1,:]),axis=1)
seis_compiled = seis_normalized

true_output = np.zeros((seis_normalized.shape[0],199))
true_output[:,0:199] = (phi_true-phi_min) / (phi_max-phi_min)

seis_plus_petro_compiled = np.concatenate((seis_compiled, true_output), axis=1)

X_train, X_test, Y_train_unmasked, Y_test_unmasked = sklearn.model_selection.train_test_split(seis_normalized, seis_plus_petro_compiled, test_size = 0.2, random_state = 1)

X_train_final = np.expand_dims(np.expand_dims(X_train, axis=1), axis=3)
X_test_final = np.expand_dims(np.expand_dims(X_test, axis=1), axis=3)
mask_output_test = Y_test_unmasked[:,0:1] - Y_test_unmasked[:,0:1]
Y_test = np.concatenate((Y_test_unmasked,mask_output_test), axis=1)
mask_output_train = Y_train_unmasked[:,0:1] - Y_train_unmasked[:,0:1]
mask_no = 4 ##number of prior known porosity logs
mask_output_train[0:mask_no, :] = 1
Y_train = np.concatenate((Y_train_unmasked,mask_output_train), axis=1)

print ("number of training examples = " + str(X_train_final.shape[0]))
print ("number of test examples = " + str(X_test_final.shape[0]))
print ("X_train shape: " + str(X_train_final.shape))
print ("Y_train shape: " + str(Y_train.shape))
print ("X_test shape: " + str(X_test_final.shape))
print ("Y_test shape: " + str(Y_test.shape))
# Out:
# number of training examples = 2000
# number of test examples = 500
# X_train shape: (2000, 1, 246, 1)
# Y_train shape: (2000, 446)
# X_test shape: (500, 1, 246, 1)
# Y_test shape: (500, 446)

# %%
## Denominators for normalizing the RMS error in the loss function
denom_phi = tf.reduce_sum(tf.where(Y_train[:,-1]==1, tf.reduce_mean(Y_train[:,246:246+199],axis=1), Y_train[:,-1]))/mask_no
np.save('output/denom_phi.npy', denom_phi)

denom_seis = tf.reduce_mean(X_train)
np.save('output/denom_seis.npy', denom_seis)
denom_phi, denom_seis
# Out:
# (<tf.Tensor: shape=(), dtype=float64, numpy=0.3626062597470109>,
#  <tf.Tensor: shape=(), dtype=float64, numpy=0.5142038419702656>)

# %%
end_time = 0.172
time_upscaled = np.arange(0, end_time, dt)
i = np.random.choice(seis.shape[0], size = 1)[0]

plt.subplot(1,2,1);
plt.plot(np.squeeze(seis[i,:]), time_upscaled);
plt.gca().invert_yaxis();
plt.ylabel('Time(s), {}'.format(i));
plt.xlabel('Before normalisation');

plt.subplot(1,2,2);
plt.plot(np.squeeze(seis_normalized[i,:]), time_upscaled);
plt.gca().invert_yaxis();
plt.xlabel('After normalisation');

# %% [markdown]
# # regressao

# %%
porosidade = Y_train[0:mask_no, 246:-1]
vepe, vese, rho = SoftSandNew(2.61, 1.01, porosidade, (1 - vclay)*0.8, vclay, (1 - vclay)*0.2, 0, 0, diffP, PhiC, Coordination, Fudge)
impedancia = (vepe * rho).numpy()

# %%
impedancia[np.isnan(impedancia)] = 0
for i in range(mask_no):
    plt.scatter(porosidade[i, :], impedancia[i, :]);

# %%
regr_lr = LinearRegression().fit(porosidade.reshape(-1, 1), impedancia.reshape(-1, 1))

for i in range(mask_no):
    plt.scatter(porosidade[i, :], impedancia[i, :], color = 'tab:blue');
    plt.scatter(porosidade[i, :], porosidade[i, :] * regr_lr.coef_+ regr_lr.intercept_, color = 'tab:orange');
regr_lr.coef_, regr_lr.intercept_
# Out:
# (array([[-11.39919887]]), array([10.10783853]))

# %%
i = np.random.choice(X_train_final.shape[0], size = 1)[0]
porosidade = Y_train[i:i+1, 246:-1]
vepe, vese, rho = SoftSandNew(2.61, 1.01, porosidade, (1 - vclay)*0.8, vclay, (1 - vclay)*0.2, 0, 0, diffP, PhiC, Coordination, Fudge)
impedancia = (vepe * rho).numpy()

plt.scatter(porosidade[0, :], impedancia[0, :]);
plt.scatter(porosidade[0, :], porosidade[0, :] * regr_lr.coef_+ regr_lr.intercept_);
i
# Out:
# 682

# %%
# beta1 = tf.Variable(initial_value = regr_lr.coef_, dtype = tf.float32, trainable = True)
# beta0 = tf.Variable(initial_value = regr_lr.intercept_, dtype = tf.float32, trainable = True)

# %%
# from tensorflow.python.keras.layers import Lambda
from tensorflow.python.keras.layers import Layer

class Linear1D(Layer):
    def __init__(self):
        super().__init__()
        # self.beta1 = self.add_weight(shape = (1, 1), initializer = initializers.Constant(regr_lr.coef_[0]), trainable = True, name = 'beta1')
        # self.beta0 = self.add_weight(shape = (1), initializer = initializers.Constant(regr_lr.intercept_[0]), trainable = True, name = 'beta0')
        # self.beta1 = self.add_weight(shape = (1, 1), initializer = 'random_normal', trainable = True, name = 'beta1')
        # self.beta0 = self.add_weight(shape = (1, 1), initializer = 'random_normal', trainable = True, name = 'beta0')
        self.beta1 = self.add_weight(shape = (1, 1), initializer = initializers.Constant(-10), trainable = True, name = 'beta1')
        self.beta0 = self.add_weight(shape = (1, 1), initializer = initializers.Constant(10), trainable = True, name = 'beta0')
    
    def call(self, inputs):
        # return inputs * self.beta1 + self.beta0
        return tf.math.multiply(inputs, self.beta1) + self.beta0
        # return tf.math.multiply(inputs, self.beta1 * 10) + self.beta0 * 10

# %% [markdown]
# # model

# %%
def DecoderLinearInterpLayer(x, xp, fp):
    i = tf.clip_by_value(tf.searchsorted(xp, x, side='right'), 1, xp.shape[1] - 1)

    fp1 = tf.gather(fp, indices=i-1, batch_dims=1)
    fp2 = tf.gather(fp, indices=i, batch_dims=1)
    xp1 = tf.gather(xp, indices=i-1, batch_dims=1)
    xp2 = tf.gather(xp, indices=i, batch_dims=1)

    f = (fp1 *  (xp2 - x) + fp2 * (x - xp1)) / (xp2 - xp1)

    left = fp[0,0]
    right = fp[-1,-1]

    ff = tf.where(x < tf.ones_like(x)*tf.expand_dims(xp[:,0],axis=1), left, f)
    fff = tf.where(x > tf.ones_like(x)*tf.expand_dims(xp[:,-1],axis=1), tf.ones_like(x)*tf.expand_dims(fp[:,-1],axis=1), ff)
    return fff

# %%
given_seed = 2

input_final = Input(shape=(X_train_final.shape[1:]))

# Encoder
#1
X = Conv2D(32, (1, 3), strides=(1, 2), name='conv0', padding='same',
           kernel_initializer=initializers.he_uniform(seed=given_seed), bias_initializer='zeros')(input_final)

#X = BatchNormalization(axis=-1, name='bn0')(X)
X = Activation('relu')(X)
#X = Dropout(rate=0.3, name='drop_conv0')(X)

#2
X = Conv2D(64, (1, 7), strides=(1, 2), name='conv1',padding='same',
           kernel_initializer=initializers.he_uniform(seed=given_seed), bias_initializer='zeros')(X)

#X = BatchNormalization(axis=-1, name='bn1')(X)
X = Activation('relu')(X)
#X = Dropout(rate=0.3, name='drop_conv1')(X)

#3
X = Conv2D(128, (1, 15), strides=(1, 2), name='conv2',padding='same',
           kernel_initializer=initializers.he_uniform(seed=given_seed), bias_initializer='zeros')(X)

#X = BatchNormalization(axis=-1, name='bn2')(X)
X = Activation('relu')(X)
#X = Dropout(rate=0.3, name='drop_conv2')(X)

#4 
X = Conv2D(256, (1, 30), strides=(1, 2), name='conv3',padding='same',
           kernel_initializer=initializers.he_uniform(seed=given_seed), bias_initializer='zeros')(X)
          
#X = BatchNormalization(axis=-1, name='bn3')(X)
X = Activation('relu')(X)
X = Dropout(rate=0.3, name='drop_conv3')(X)

# FLATTEN X + FULLYCONNECTED
X = Flatten()(X)
    
X = Dense(199, name='fc0',
          kernel_initializer=initializers.he_uniform(seed=given_seed), bias_initializer='zeros')(X)

encoded = Activation('tanh')(X) ##to scale the output between –1 and 1 before passing it as input to the decoder

# Decoder
encoded = tf.cast(encoded, tf.float64)

phi_for = ((encoded + 1) / 2) ##scaled between 0 and 1

phi = phi_for * (phi_max - phi_min) + phi_min + 1e-07

depth = np.arange(1, phi.shape[1]+1) * diffDepth

RHOf = sw*RHOw + (1 - sw) * RHOg
Kf = 1/(sw/Kw + (1 - sw)/Kg)

Vp_final, Vs_final, RHO_final = SoftSandNew(Kf, RHOf, phi, (1 - vclay)*0.8, vclay, (1 - vclay)*0.2, 0, 0, diffP, PhiC, Coordination, Fudge)
# impedance_final = Vp_final * RHO_final

# impedance_final = phi * regr_lr.coef_ + regr_lr.intercept_
# impedance_final = phi * beta1 + beta0
impedance_final = Linear1D()(phi)

impedance_final = tf.cast(impedance_final, tf.float64)

#Seismic part

depth_diff = np.mean(np.diff(depth.T))
time0 = 0.0/(Vp_final[:,0])
# time0 = 0.0/(impedance_final[:,0])
time1 = 2*tf.cumsum(depth_diff/(Vp_final*1e3),axis=1)
# time1 = 2*tf.cumsum(depth_diff/(impedance_final*1e3),axis=1)
time_final = tf.concat([tf.expand_dims(time0, axis=1),time1],axis=1)
time = time_final[:,0:-1]

time_new = tf.ones_like(time, dtype=tf.float64)
for i in range(len(time_upscaled) - time.shape[1]):
    time_new = tf.concat([time_new,tf.expand_dims(time0+1.0,axis=1)],axis=1)
pred_t = time_new*time_upscaled

# Vp_time = DecoderLinearInterpLayer(pred_t, time, Vp_final)
# RHO_time = DecoderLinearInterpLayer(pred_t, time, RHO_final)
impedance_time = DecoderLinearInterpLayer(pred_t, time, impedance_final)

# Rpp_0 = RC_fwd_model(Vp_time[:,0:-1], RHO_time[:,0:-1], Vp_time[:,1:], RHO_time[:,1:])
Rpp_0 = RC_fwd_model_ia(impedance_time[:,0:-1], impedance_time[:,1:])
# Rpplast = 0.0 / (Vp_time[:,0])
Rpplast = 0.0 / (impedance_time[:,0])
Rpp0 = tf.concat([Rpp_0, tf.expand_dims(Rpplast, axis=1)], axis=1)

kernel_wvlt = tf.reshape(wvlt, [int(wvlt.shape[0]), 1, 1])
RC0 = tf.expand_dims(Rpp0, axis=2)
seis_for0 = tf.squeeze(tf.nn.conv1d(RC0, tf.reverse(kernel_wvlt,[0]), 1,'SAME'),axis=2)
    
seis_for_normalized = (seis_for0 - np.min(seis))/(np.max(seis)-np.min(seis))

seis_for_final = tf.concat([seis_for_normalized, phi_for],axis=1)

# %%
impedance_time.shape, Rpp_0.shape, Rpplast.shape, Rpp0.shape
# Out:
# (TensorShape([None, 246]),
#  TensorShape([None, 245]),
#  TensorShape([None]),
#  TensorShape([None, 246]))

# %%
kernel_wvlt.shape, RC0.shape
# Out:
# (TensorShape([60, 1, 1]), TensorShape([None, 246, 1]))

# %% [markdown]
# x (sismica) -> CNN -> phi (porosidade) \
# phi . beta + cte = impendance (vp * rho) \
# compute_reflectivity_coefficients(impendace) -> Rpp (refletividade) \
# rpp conv wavelet -> x (sismica)

# %%
rw_pinn = Model(inputs = input_final, outputs = seis_for_final)
rw_pinn.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 1, 246, 1)]  0
# __________________________________________________________________________________________________
# conv0 (Conv2D)                  (None, 1, 123, 32)   128         input_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 1, 123, 32)   0           conv0[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 1, 62, 64)    14400       activation[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 1, 62, 64)    0           conv1[0][0]
# __________________________________________________________________________________________________
# conv2 (Conv2D)                  (None, 1, 31, 128)   123008      activation_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 1, 31, 128)   0           conv2[0][0]
# __________________________________________________________________________________________________
# conv3 (Conv2D)                  (None, 1, 16, 256)   983296      activation_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 1, 16, 256)   0           conv3[0][0]
# __________________________________________________________________________________________________
# drop_conv3 (Dropout)            (None, 1, 16, 256)   0           activation_3[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 4096)         0           drop_conv3[0][0]
# __________________________________________________________________________________________________
# fc0 (Dense)                     (None, 199)          815303      flatten[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 199)          0           fc0[0][0]
# __________________________________________________________________________________________________
# tf.cast (TFOpLambda)            (None, 199)          0           activation_4[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add (TFOpLambd (None, 199)          0           tf.cast[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv (TFOpLambda)    (None, 199)          0           tf.__operators__.add[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply (TFOpLambda)   (None, 199)          0           tf.math.truediv[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_1 (TFOpLam (None, 199)          0           tf.math.multiply[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_2 (TFOpLam (None, 199)          0           tf.__operators__.add_1[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_2 (TFOpLambda) (None, 199)          0           tf.__operators__.add_2[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_9 (TFOpLambda) (None, 199)          0           tf.__operators__.add_2[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_10 (TFOpLambda (None, 199)          0           tf.__operators__.add_2[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract (TFOpLambda)   (None, 199)          0           tf.__operators__.add_2[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_6 (TFOpLambda)  (None, 199)          0           tf.__operators__.add_2[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_8 (TFOpLambda)  (None, 199)          0           tf.math.subtract_2[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_6 (TFOpLambda) (None, 199)          0           tf.__operators__.add_2[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_7 (TFOpLambda) (None, 199)          0           tf.__operators__.add_2[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_19 (TFOpLambda) (None, 199)          0           tf.math.subtract_9[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_21 (TFOpLambda) (None, 199)          0           tf.math.subtract_10[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_1 (TFOpLambda)  (None, 199)          0           tf.__operators__.add_2[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_3 (TFOpLambda)  (None, 199)          0           tf.math.subtract[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_7 (TFOpLambda)  (None, 199)          0           tf.math.truediv_6[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_9 (TFOpLambda)  (None, 199)          0           tf.math.truediv_8[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_14 (TFOpLambda) (None, 199)          0           tf.math.subtract_6[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_16 (TFOpLambda) (None, 199)          0           tf.math.subtract_7[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_20 (TFOpLambda) (None, 199)          0           tf.math.truediv_19[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_22 (TFOpLambda) (None, 199)          0           tf.math.truediv_21[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_2 (TFOpLambda)  (None, 199)          0           tf.math.truediv_1[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_4 (TFOpLambda)  (None, 199)          0           tf.math.truediv_3[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_4 (TFOpLam (None, 199)          0           tf.math.truediv_7[0][0]
#                                                                  tf.math.truediv_9[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_15 (TFOpLambda) (None, 199)          0           tf.math.truediv_14[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_17 (TFOpLambda) (None, 199)          0           tf.math.truediv_16[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_7 (TFOpLam (None, 199)          0           tf.math.truediv_20[0][0]
#                                                                  tf.math.truediv_22[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_3 (TFOpLam (None, 199)          0           tf.math.truediv_2[0][0]
#                                                                  tf.math.truediv_4[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_10 (TFOpLambda) (None, 199)          0           tf.__operators__.add_4[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_6 (TFOpLam (None, 199)          0           tf.math.truediv_15[0][0]
#                                                                  tf.math.truediv_17[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_23 (TFOpLambda) (None, 199)          0           tf.__operators__.add_7[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_5 (TFOpLambda)  (None, 199)          0           tf.__operators__.add_3[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_3 (TFOpLambda) (None, 199)          0           tf.math.truediv_10[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_18 (TFOpLambda) (None, 199)          0           tf.__operators__.add_6[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_11 (TFOpLambda (None, 199)          0           tf.math.truediv_23[0][0]
# __________________________________________________________________________________________________
# tf.math.less_equal_1 (TFOpLambd (None, 199)          0           tf.__operators__.add_2[0][0]
# __________________________________________________________________________________________________
# tf.math.greater_1 (TFOpLambda)  (None, 199)          0           tf.__operators__.add_2[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_1 (TFOpLambda) (None, 199)          0           tf.math.truediv_5[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_1 (TFOpLambda) (None, 199)          0           tf.math.subtract_3[0][0]
# __________________________________________________________________________________________________
# tf.math.less_equal (TFOpLambda) (None, 199)          0           tf.__operators__.add_2[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_8 (TFOpLambda) (None, 199)          0           tf.math.truediv_18[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_3 (TFOpLambda) (None, 199)          0           tf.math.subtract_11[0][0]
# __________________________________________________________________________________________________
# tf.math.greater (TFOpLambda)    (None, 199)          0           tf.__operators__.add_2[0][0]
# __________________________________________________________________________________________________
# tf.cast_3 (TFOpLambda)          (None, 199)          0           tf.math.less_equal_1[0][0]
# __________________________________________________________________________________________________
# tf.cast_4 (TFOpLambda)          (None, 199)          0           tf.math.greater_1[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_5 (TFOpLam (None, 199)          0           tf.math.subtract_1[0][0]
#                                                                  tf.math.multiply_1[0][0]
# __________________________________________________________________________________________________
# tf.cast_1 (TFOpLambda)          (None, 199)          0           tf.math.less_equal[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_8 (TFOpLam (None, 199)          0           tf.math.subtract_8[0][0]
#                                                                  tf.math.multiply_3[0][0]
# __________________________________________________________________________________________________
# tf.cast_2 (TFOpLambda)          (None, 199)          0           tf.math.greater[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_7 (TFOpLambda) (None, 199)          0           tf.math.subtract_3[0][0]
#                                                                  tf.cast_3[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_8 (TFOpLambda) (None, 199)          0           tf.math.subtract_11[0][0]
#                                                                  tf.cast_4[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_5 (TFOpLambda) (None, 199)          0           tf.__operators__.add_5[0][0]
#                                                                  tf.cast_1[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_6 (TFOpLambda) (None, 199)          0           tf.__operators__.add_8[0][0]
#                                                                  tf.cast_2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_10 (TFOpLa (None, 199)          0           tf.math.multiply_7[0][0]
#                                                                  tf.math.multiply_8[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_9 (TFOpLam (None, 199)          0           tf.math.multiply_5[0][0]
#                                                                  tf.math.multiply_6[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_11 (TFOpLambda (None, 199)          0           tf.__operators__.add_10[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_12 (TFOpLa (None, 199)          0           tf.__operators__.add_2[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_14 (TFOpLambda (None, 199)          0           tf.__operators__.add_9[0][0]
#                                                                  tf.math.multiply_11[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_13 (TFOpLambda (None, 199)          0           tf.__operators__.add_12[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_14 (TFOpLambda (None, 199)          0           tf.math.multiply_13[0][0]
#                                                                  tf.math.subtract_14[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_12 (TFOpLambda (None, 199)          0           tf.__operators__.add_2[0][0]
#                                                                  tf.math.subtract_14[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_27 (TFOpLambda) (None, 199)          0           tf.math.multiply_14[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_16 (TFOpLambda (None, 199)          0           tf.__operators__.add_2[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_15 (TFOpLambda (None, 199)          0           tf.math.multiply_12[0][0]
#                                                                  tf.math.truediv_27[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_16 (TFOpLambda (None, 199)          0           tf.math.subtract_16[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_17 (TFOpLambda (None, 199)          0           tf.__operators__.add_2[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_18 (TFOpLambda (None, 199)          0           tf.math.subtract_14[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_13 (TFOpLa (None, 199)          0           tf.math.subtract_15[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_14 (TFOpLa (None, 199)          0           tf.math.multiply_16[0][0]
#                                                                  tf.math.multiply_17[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_28 (TFOpLambda) (None, 199)          0           tf.math.multiply_18[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_15 (TFOpLambda (None, 199)          0           tf.__operators__.add_13[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_17 (TFOpLambda (None, 199)          0           tf.__operators__.add_14[0][0]
#                                                                  tf.math.truediv_28[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_18 (TFOpLambda (None, 199)          0           tf.__operators__.add_2[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_29 (TFOpLambda) (None, 199)          0           tf.math.multiply_15[0][0]
#                                                                  tf.math.subtract_17[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_19 (TFOpLambda (None, 199)          0           tf.__operators__.add_10[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_20 (TFOpLambda (None, 199)          0           tf.math.subtract_18[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_21 (TFOpLambda (None, 199)          0           tf.__operators__.add_2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_15 (TFOpLa (None, 199)          0           tf.math.truediv_29[0][0]
#                                                                  tf.math.multiply_19[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_16 (TFOpLa (None, 199)          0           tf.math.multiply_20[0][0]
#                                                                  tf.math.multiply_21[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_30 (TFOpLambda) (None, 199)          0           tf.__operators__.add_15[0][0]
#                                                                  tf.__operators__.add_16[0][0]
# __________________________________________________________________________________________________
# tf.math.pow (TFOpLambda)        (None, 199)          0           tf.math.truediv_30[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_24 (TFOpLambda (None, 199)          0           tf.math.pow[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem (Slici (None,)              0           tf.math.pow[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_36 (TFOpLambda) (None, 199)          0           tf.math.multiply_24[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_35 (TFOpLambda) (None,)              0           tf.__operators__.getitem[0][0]
# __________________________________________________________________________________________________
# tf.math.cumsum (TFOpLambda)     (None, 199)          0           tf.math.truediv_36[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims (TFOpLambda)     (None, 1)            0           tf.math.truediv_35[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_25 (TFOpLambda (None, 199)          0           tf.math.cumsum[0][0]
# __________________________________________________________________________________________________
# tf.concat (TFOpLambda)          (None, 200)          0           tf.expand_dims[0][0]
#                                                                  tf.math.multiply_25[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1 (Sli (None, 199)          0           tf.concat[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_17 (TFOpLa (None,)              0           tf.math.truediv_35[0][0]
# __________________________________________________________________________________________________
# tf.ones_like (TFOpLambda)       (None, 199)          0           tf.__operators__.getitem_1[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_1 (TFOpLambda)   (None, 1)            0           tf.__operators__.add_17[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_18 (TFOpLa (None,)              0           tf.math.truediv_35[0][0]
# __________________________________________________________________________________________________
# tf.concat_1 (TFOpLambda)        (None, 200)          0           tf.ones_like[0][0]
#                                                                  tf.expand_dims_1[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_2 (TFOpLambda)   (None, 1)            0           tf.__operators__.add_18[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_19 (TFOpLa (None,)              0           tf.math.truediv_35[0][0]
# __________________________________________________________________________________________________
# tf.concat_2 (TFOpLambda)        (None, 201)          0           tf.concat_1[0][0]
#                                                                  tf.expand_dims_2[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_3 (TFOpLambda)   (None, 1)            0           tf.__operators__.add_19[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_20 (TFOpLa (None,)              0           tf.math.truediv_35[0][0]
# __________________________________________________________________________________________________
# tf.concat_3 (TFOpLambda)        (None, 202)          0           tf.concat_2[0][0]
#                                                                  tf.expand_dims_3[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_4 (TFOpLambda)   (None, 1)            0           tf.__operators__.add_20[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_21 (TFOpLa (None,)              0           tf.math.truediv_35[0][0]
# __________________________________________________________________________________________________
# tf.concat_4 (TFOpLambda)        (None, 203)          0           tf.concat_3[0][0]
#                                                                  tf.expand_dims_4[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_5 (TFOpLambda)   (None, 1)            0           tf.__operators__.add_21[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_22 (TFOpLa (None,)              0           tf.math.truediv_35[0][0]
# __________________________________________________________________________________________________
# tf.concat_5 (TFOpLambda)        (None, 204)          0           tf.concat_4[0][0]
#                                                                  tf.expand_dims_5[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_6 (TFOpLambda)   (None, 1)            0           tf.__operators__.add_22[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_23 (TFOpLa (None,)              0           tf.math.truediv_35[0][0]
# __________________________________________________________________________________________________
# tf.concat_6 (TFOpLambda)        (None, 205)          0           tf.concat_5[0][0]
#                                                                  tf.expand_dims_6[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_7 (TFOpLambda)   (None, 1)            0           tf.__operators__.add_23[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_24 (TFOpLa (None,)              0           tf.math.truediv_35[0][0]
# __________________________________________________________________________________________________
# tf.concat_7 (TFOpLambda)        (None, 206)          0           tf.concat_6[0][0]
#                                                                  tf.expand_dims_7[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_8 (TFOpLambda)   (None, 1)            0           tf.__operators__.add_24[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_25 (TFOpLa (None,)              0           tf.math.truediv_35[0][0]
# __________________________________________________________________________________________________
# tf.concat_8 (TFOpLambda)        (None, 207)          0           tf.concat_7[0][0]
#                                                                  tf.expand_dims_8[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_9 (TFOpLambda)   (None, 1)            0           tf.__operators__.add_25[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_26 (TFOpLa (None,)              0           tf.math.truediv_35[0][0]
# __________________________________________________________________________________________________
# tf.concat_9 (TFOpLambda)        (None, 208)          0           tf.concat_8[0][0]
#                                                                  tf.expand_dims_9[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_10 (TFOpLambda)  (None, 1)            0           tf.__operators__.add_26[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_27 (TFOpLa (None,)              0           tf.math.truediv_35[0][0]
# __________________________________________________________________________________________________
# tf.concat_10 (TFOpLambda)       (None, 209)          0           tf.concat_9[0][0]
#                                                                  tf.expand_dims_10[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_11 (TFOpLambda)  (None, 1)            0           tf.__operators__.add_27[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_28 (TFOpLa (None,)              0           tf.math.truediv_35[0][0]
# __________________________________________________________________________________________________
# tf.concat_11 (TFOpLambda)       (None, 210)          0           tf.concat_10[0][0]
#                                                                  tf.expand_dims_11[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_12 (TFOpLambda)  (None, 1)            0           tf.__operators__.add_28[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_29 (TFOpLa (None,)              0           tf.math.truediv_35[0][0]
# __________________________________________________________________________________________________
# tf.concat_12 (TFOpLambda)       (None, 211)          0           tf.concat_11[0][0]
#                                                                  tf.expand_dims_12[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_13 (TFOpLambda)  (None, 1)            0           tf.__operators__.add_29[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_30 (TFOpLa (None,)              0           tf.math.truediv_35[0][0]
# __________________________________________________________________________________________________
# tf.concat_13 (TFOpLambda)       (None, 212)          0           tf.concat_12[0][0]
#                                                                  tf.expand_dims_13[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_14 (TFOpLambda)  (None, 1)            0           tf.__operators__.add_30[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_31 (TFOpLa (None,)              0           tf.math.truediv_35[0][0]
# __________________________________________________________________________________________________
# tf.concat_14 (TFOpLambda)       (None, 213)          0           tf.concat_13[0][0]
#                                                                  tf.expand_dims_14[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_15 (TFOpLambda)  (None, 1)            0           tf.__operators__.add_31[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_32 (TFOpLa (None,)              0           tf.math.truediv_35[0][0]
# __________________________________________________________________________________________________
# tf.concat_15 (TFOpLambda)       (None, 214)          0           tf.concat_14[0][0]
#                                                                  tf.expand_dims_15[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_16 (TFOpLambda)  (None, 1)            0           tf.__operators__.add_32[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_33 (TFOpLa (None,)              0           tf.math.truediv_35[0][0]
# __________________________________________________________________________________________________
# tf.concat_16 (TFOpLambda)       (None, 215)          0           tf.concat_15[0][0]
#                                                                  tf.expand_dims_16[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_17 (TFOpLambda)  (None, 1)            0           tf.__operators__.add_33[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_34 (TFOpLa (None,)              0           tf.math.truediv_35[0][0]
# __________________________________________________________________________________________________
# tf.concat_17 (TFOpLambda)       (None, 216)          0           tf.concat_16[0][0]
#                                                                  tf.expand_dims_17[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_18 (TFOpLambda)  (None, 1)            0           tf.__operators__.add_34[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_35 (TFOpLa (None,)              0           tf.math.truediv_35[0][0]
# __________________________________________________________________________________________________
# tf.concat_18 (TFOpLambda)       (None, 217)          0           tf.concat_17[0][0]
#                                                                  tf.expand_dims_18[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_19 (TFOpLambda)  (None, 1)            0           tf.__operators__.add_35[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_36 (TFOpLa (None,)              0           tf.math.truediv_35[0][0]
# __________________________________________________________________________________________________
# tf.concat_19 (TFOpLambda)       (None, 218)          0           tf.concat_18[0][0]
#                                                                  tf.expand_dims_19[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_20 (TFOpLambda)  (None, 1)            0           tf.__operators__.add_36[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_37 (TFOpLa (None,)              0           tf.math.truediv_35[0][0]
# __________________________________________________________________________________________________
# tf.concat_20 (TFOpLambda)       (None, 219)          0           tf.concat_19[0][0]
#                                                                  tf.expand_dims_20[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_21 (TFOpLambda)  (None, 1)            0           tf.__operators__.add_37[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_38 (TFOpLa (None,)              0           tf.math.truediv_35[0][0]
# __________________________________________________________________________________________________
# tf.concat_21 (TFOpLambda)       (None, 220)          0           tf.concat_20[0][0]
#                                                                  tf.expand_dims_21[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_22 (TFOpLambda)  (None, 1)            0           tf.__operators__.add_38[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_39 (TFOpLa (None,)              0           tf.math.truediv_35[0][0]
# __________________________________________________________________________________________________
# tf.concat_22 (TFOpLambda)       (None, 221)          0           tf.concat_21[0][0]
#                                                                  tf.expand_dims_22[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_23 (TFOpLambda)  (None, 1)            0           tf.__operators__.add_39[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_40 (TFOpLa (None,)              0           tf.math.truediv_35[0][0]
# __________________________________________________________________________________________________
# tf.concat_23 (TFOpLambda)       (None, 222)          0           tf.concat_22[0][0]
#                                                                  tf.expand_dims_23[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_24 (TFOpLambda)  (None, 1)            0           tf.__operators__.add_40[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_41 (TFOpLa (None,)              0           tf.math.truediv_35[0][0]
# __________________________________________________________________________________________________
# tf.concat_24 (TFOpLambda)       (None, 223)          0           tf.concat_23[0][0]
#                                                                  tf.expand_dims_24[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_25 (TFOpLambda)  (None, 1)            0           tf.__operators__.add_41[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_42 (TFOpLa (None,)              0           tf.math.truediv_35[0][0]
# __________________________________________________________________________________________________
# tf.concat_25 (TFOpLambda)       (None, 224)          0           tf.concat_24[0][0]
#                                                                  tf.expand_dims_25[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_26 (TFOpLambda)  (None, 1)            0           tf.__operators__.add_42[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_43 (TFOpLa (None,)              0           tf.math.truediv_35[0][0]
# __________________________________________________________________________________________________
# tf.concat_26 (TFOpLambda)       (None, 225)          0           tf.concat_25[0][0]
#                                                                  tf.expand_dims_26[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_27 (TFOpLambda)  (None, 1)            0           tf.__operators__.add_43[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_44 (TFOpLa (None,)              0           tf.math.truediv_35[0][0]
# __________________________________________________________________________________________________
# tf.concat_27 (TFOpLambda)       (None, 226)          0           tf.concat_26[0][0]
#                                                                  tf.expand_dims_27[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_28 (TFOpLambda)  (None, 1)            0           tf.__operators__.add_44[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_45 (TFOpLa (None,)              0           tf.math.truediv_35[0][0]
# __________________________________________________________________________________________________
# tf.concat_28 (TFOpLambda)       (None, 227)          0           tf.concat_27[0][0]
#                                                                  tf.expand_dims_28[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_29 (TFOpLambda)  (None, 1)            0           tf.__operators__.add_45[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_46 (TFOpLa (None,)              0           tf.math.truediv_35[0][0]
# __________________________________________________________________________________________________
# tf.concat_29 (TFOpLambda)       (None, 228)          0           tf.concat_28[0][0]
#                                                                  tf.expand_dims_29[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_30 (TFOpLambda)  (None, 1)            0           tf.__operators__.add_46[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_47 (TFOpLa (None,)              0           tf.math.truediv_35[0][0]
# __________________________________________________________________________________________________
# tf.concat_30 (TFOpLambda)       (None, 229)          0           tf.concat_29[0][0]
#                                                                  tf.expand_dims_30[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_31 (TFOpLambda)  (None, 1)            0           tf.__operators__.add_47[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_48 (TFOpLa (None,)              0           tf.math.truediv_35[0][0]
# __________________________________________________________________________________________________
# tf.concat_31 (TFOpLambda)       (None, 230)          0           tf.concat_30[0][0]
#                                                                  tf.expand_dims_31[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_32 (TFOpLambda)  (None, 1)            0           tf.__operators__.add_48[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_49 (TFOpLa (None,)              0           tf.math.truediv_35[0][0]
# __________________________________________________________________________________________________
# tf.concat_32 (TFOpLambda)       (None, 231)          0           tf.concat_31[0][0]
#                                                                  tf.expand_dims_32[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_33 (TFOpLambda)  (None, 1)            0           tf.__operators__.add_49[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_50 (TFOpLa (None,)              0           tf.math.truediv_35[0][0]
# __________________________________________________________________________________________________
# tf.concat_33 (TFOpLambda)       (None, 232)          0           tf.concat_32[0][0]
#                                                                  tf.expand_dims_33[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_34 (TFOpLambda)  (None, 1)            0           tf.__operators__.add_50[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_51 (TFOpLa (None,)              0           tf.math.truediv_35[0][0]
# __________________________________________________________________________________________________
# tf.concat_34 (TFOpLambda)       (None, 233)          0           tf.concat_33[0][0]
#                                                                  tf.expand_dims_34[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_35 (TFOpLambda)  (None, 1)            0           tf.__operators__.add_51[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_52 (TFOpLa (None,)              0           tf.math.truediv_35[0][0]
# __________________________________________________________________________________________________
# ...
# tf.expand_dims_43 (TFOpLambda)  (None, 1)            0           tf.__operators__.add_59[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_60 (TFOpLa (None,)              0           tf.math.truediv_35[0][0]
# __________________________________________________________________________________________________
# tf.concat_43 (TFOpLambda)       (None, 242)          0           tf.concat_42[0][0]
#                                                                  tf.expand_dims_43[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_44 (TFOpLambda)  (None, 1)            0           tf.__operators__.add_60[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_61 (TFOpLa (None,)              0           tf.math.truediv_35[0][0]
# __________________________________________________________________________________________________
# tf.concat_44 (TFOpLambda)       (None, 243)          0           tf.concat_43[0][0]
#                                                                  tf.expand_dims_44[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_45 (TFOpLambda)  (None, 1)            0           tf.__operators__.add_61[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_62 (TFOpLa (None,)              0           tf.math.truediv_35[0][0]
# __________________________________________________________________________________________________
# tf.concat_45 (TFOpLambda)       (None, 244)          0           tf.concat_44[0][0]
#                                                                  tf.expand_dims_45[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_46 (TFOpLambda)  (None, 1)            0           tf.__operators__.add_62[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_63 (TFOpLa (None,)              0           tf.math.truediv_35[0][0]
# __________________________________________________________________________________________________
# tf.concat_46 (TFOpLambda)       (None, 245)          0           tf.concat_45[0][0]
#                                                                  tf.expand_dims_46[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_47 (TFOpLambda)  (None, 1)            0           tf.__operators__.add_63[0][0]
# __________________________________________________________________________________________________
# tf.concat_47 (TFOpLambda)       (None, 246)          0           tf.concat_46[0][0]
#                                                                  tf.expand_dims_47[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_26 (TFOpLambda (None, 246)          0           tf.concat_47[0][0]
# __________________________________________________________________________________________________
# tf.searchsorted (TFOpLambda)    (None, 246)          0           tf.__operators__.getitem_1[0][0]
#                                                                  tf.math.multiply_26[0][0]
# __________________________________________________________________________________________________
# tf.clip_by_value (TFOpLambda)   (None, 246)          0           tf.searchsorted[0][0]
# __________________________________________________________________________________________________
# linear1d (Linear1D)             (None, 199)          2           tf.__operators__.add_2[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_22 (TFOpLambda (None, 246)          0           tf.clip_by_value[0][0]
# __________________________________________________________________________________________________
# tf.cast_7 (TFOpLambda)          (None, 199)          0           linear1d[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_21 (TFOpLambda (None, 246)          0           tf.clip_by_value[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.gather_3 (TFOpLamb (None, 246)          0           tf.__operators__.getitem_1[0][0]
#                                                                  tf.clip_by_value[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.gather_2 (TFOpLamb (None, 246)          0           tf.__operators__.getitem_1[0][0]
#                                                                  tf.math.subtract_22[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_4 (Sli (None,)              0           tf.__operators__.getitem_1[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.gather (TFOpLambda (None, 246)          0           tf.cast_7[0][0]
#                                                                  tf.math.subtract_21[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_23 (TFOpLambda (None, 246)          0           tf.compat.v1.gather_3[0][0]
#                                                                  tf.math.multiply_26[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.gather_1 (TFOpLamb (None, 246)          0           tf.cast_7[0][0]
#                                                                  tf.clip_by_value[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_24 (TFOpLambda (None, 246)          0           tf.math.multiply_26[0][0]
#                                                                  tf.compat.v1.gather_2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_5 (Sli (None,)              0           tf.__operators__.getitem_1[0][0]
# __________________________________________________________________________________________________
# tf.ones_like_1 (TFOpLambda)     (None, 246)          0           tf.math.multiply_26[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_48 (TFOpLambda)  (None, 1)            0           tf.__operators__.getitem_4[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_27 (TFOpLambda (None, 246)          0           tf.compat.v1.gather[0][0]
#                                                                  tf.math.subtract_23[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_28 (TFOpLambda (None, 246)          0           tf.compat.v1.gather_1[0][0]
#                                                                  tf.math.subtract_24[0][0]
# __________________________________________________________________________________________________
# tf.ones_like_2 (TFOpLambda)     (None, 246)          0           tf.math.multiply_26[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_49 (TFOpLambda)  (None, 1)            0           tf.__operators__.getitem_5[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_6 (Sli (None,)              0           tf.cast_7[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_29 (TFOpLambda (None, 246)          0           tf.ones_like_1[0][0]
#                                                                  tf.expand_dims_48[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_64 (TFOpLa (None, 246)          0           tf.math.multiply_27[0][0]
#                                                                  tf.math.multiply_28[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_25 (TFOpLambda (None, 246)          0           tf.compat.v1.gather_3[0][0]
#                                                                  tf.compat.v1.gather_2[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_30 (TFOpLambda (None, 246)          0           tf.ones_like_2[0][0]
#                                                                  tf.expand_dims_49[0][0]
# __________________________________________________________________________________________________
# tf.ones_like_3 (TFOpLambda)     (None, 246)          0           tf.math.multiply_26[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_50 (TFOpLambda)  (None, 1)            0           tf.__operators__.getitem_6[0][0]
# __________________________________________________________________________________________________
# tf.math.less (TFOpLambda)       (None, 246)          0           tf.math.multiply_26[0][0]
#                                                                  tf.math.multiply_29[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_2 (Sli ()                   0           tf.cast_7[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_37 (TFOpLambda) (None, 246)          0           tf.__operators__.add_64[0][0]
#                                                                  tf.math.subtract_25[0][0]
# __________________________________________________________________________________________________
# tf.math.greater_3 (TFOpLambda)  (None, 246)          0           tf.math.multiply_26[0][0]
#                                                                  tf.math.multiply_30[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_31 (TFOpLambda (None, 246)          0           tf.ones_like_3[0][0]
#                                                                  tf.expand_dims_50[0][0]
# __________________________________________________________________________________________________
# tf.where (TFOpLambda)           (None, 246)          0           tf.math.less[0][0]
#                                                                  tf.__operators__.getitem_2[0][0]
#                                                                  tf.math.truediv_37[0][0]
# __________________________________________________________________________________________________
# tf.where_1 (TFOpLambda)         (None, 246)          0           tf.math.greater_3[0][0]
#                                                                  tf.math.multiply_31[0][0]
#                                                                  tf.where[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_8 (Sli (None, 245)          0           tf.where_1[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_7 (Sli (None, 245)          0           tf.where_1[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_9 (Sli (None,)              0           tf.where_1[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_26 (TFOpLambda (None, 245)          0           tf.__operators__.getitem_8[0][0]
#                                                                  tf.__operators__.getitem_7[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_65 (TFOpLa (None, 245)          0           tf.__operators__.getitem_8[0][0]
#                                                                  tf.__operators__.getitem_7[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_39 (TFOpLambda) (None,)              0           tf.__operators__.getitem_9[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_38 (TFOpLambda) (None, 245)          0           tf.math.subtract_26[0][0]
#                                                                  tf.__operators__.add_65[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_51 (TFOpLambda)  (None, 1)            0           tf.math.truediv_39[0][0]
# __________________________________________________________________________________________________
# tf.concat_48 (TFOpLambda)       (None, 246)          0           tf.math.truediv_38[0][0]
#                                                                  tf.expand_dims_51[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_52 (TFOpLambda)  (None, 246, 1)       0           tf.concat_48[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.conv1d (TFOpLam (None, 246, 1)       0           tf.expand_dims_52[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.squeeze (TFOpLambd (None, 246)          0           tf.compat.v1.nn.conv1d[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_27 (TFOpLambda (None, 246)          0           tf.compat.v1.squeeze[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_40 (TFOpLambda) (None, 246)          0           tf.math.subtract_27[0][0]
# __________________________________________________________________________________________________
# tf.concat_49 (TFOpLambda)       (None, 445)          0           tf.math.truediv_40[0][0]
#                                                                  tf.math.truediv[0][0]
# ==================================================================================================
# Total params: 1,936,137
# Trainable params: 1,936,137
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # train

# %%
class loss_func(tf.keras.losses.Loss):
    def __init__(self):
        super().__init__()
    def call(self, y_true, y_pred):
        mse_seis1 = tf.reduce_mean(tf.square(y_pred[:,0:246] - y_true[:,0:246]))
        
        return tf.math.sqrt(mse_seis1)

# %%
adam = tf.keras.optimizers.Adam(learning_rate=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-07, amsgrad=False)
rw_pinn.compile(loss = loss_func(), optimizer = adam)

# %%
# Using early stopping and Model Checkpoint
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=200)
mc = ModelCheckpoint('output/rwpinn_model.h5', monitor='val_loss', mode='min', verbose=1, save_weights_only=True)

# %%
# Start the training

Batch_size = 128
history = rw_pinn.fit(X_train_final, Y_train, 
                      validation_split=0.2, epochs=200, 
                      batch_size=Batch_size, callbacks=[es, mc], verbose = 1)
# Out:
# 2024-08-12 18:04:39.381366: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2024-08-12 18:04:39.399409: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2799925000 Hz
# Epoch 1/200
# 2024-08-12 18:04:41.901402: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2024-08-12 18:04:42.265123: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2024-08-12 18:04:42.271849: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 13/13 [==============================] - 5s 67ms/step - loss: 0.1258 - val_loss: 0.0984
#
# Epoch 00001: saving model to output/rwpinn_model.h5
# Epoch 2/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0967 - val_loss: 0.0685
#
# Epoch 00002: saving model to output/rwpinn_model.h5
# Epoch 3/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0703 - val_loss: 0.0531
#
# Epoch 00003: saving model to output/rwpinn_model.h5
# Epoch 4/200
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0573 - val_loss: 0.0445
#
# Epoch 00004: saving model to output/rwpinn_model.h5
# Epoch 5/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0485 - val_loss: 0.0390
#
# Epoch 00005: saving model to output/rwpinn_model.h5
# Epoch 6/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0441 - val_loss: 0.0352
#
# Epoch 00006: saving model to output/rwpinn_model.h5
# Epoch 7/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0402 - val_loss: 0.0322
#
# Epoch 00007: saving model to output/rwpinn_model.h5
# Epoch 8/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0375 - val_loss: 0.0299
#
# Epoch 00008: saving model to output/rwpinn_model.h5
# Epoch 9/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0351 - val_loss: 0.0280
#
# Epoch 00009: saving model to output/rwpinn_model.h5
# Epoch 10/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0337 - val_loss: 0.0269
#
# Epoch 00010: saving model to output/rwpinn_model.h5
# Epoch 11/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0318 - val_loss: 0.0257
#
# Epoch 00011: saving model to output/rwpinn_model.h5
# Epoch 12/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0307 - val_loss: 0.0247
#
# Epoch 00012: saving model to output/rwpinn_model.h5
# Epoch 13/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0297 - val_loss: 0.0241
#
# Epoch 00013: saving model to output/rwpinn_model.h5
# Epoch 14/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0286 - val_loss: 0.0230
#
# Epoch 00014: saving model to output/rwpinn_model.h5
# Epoch 15/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0279 - val_loss: 0.0224
#
# Epoch 00015: saving model to output/rwpinn_model.h5
# Epoch 16/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0276 - val_loss: 0.0223
#
# Epoch 00016: saving model to output/rwpinn_model.h5
# Epoch 17/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0267 - val_loss: 0.0216
#
# Epoch 00017: saving model to output/rwpinn_model.h5
# Epoch 18/200
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0259 - val_loss: 0.0211
#
# Epoch 00018: saving model to output/rwpinn_model.h5
# Epoch 19/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0253 - val_loss: 0.0204
#
# Epoch 00019: saving model to output/rwpinn_model.h5
# Epoch 20/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0247 - val_loss: 0.0202
#
# Epoch 00020: saving model to output/rwpinn_model.h5
# Epoch 21/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0243 - val_loss: 0.0194
#
# Epoch 00021: saving model to output/rwpinn_model.h5
# Epoch 22/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0240 - val_loss: 0.0194
#
# Epoch 00022: saving model to output/rwpinn_model.h5
# Epoch 23/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0235 - val_loss: 0.0190
#
# Epoch 00023: saving model to output/rwpinn_model.h5
# Epoch 24/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0231 - val_loss: 0.0186
#
# Epoch 00024: saving model to output/rwpinn_model.h5
# Epoch 25/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0228 - val_loss: 0.0186
#
# Epoch 00025: saving model to output/rwpinn_model.h5
# Epoch 26/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0225 - val_loss: 0.0182
#
# Epoch 00026: saving model to output/rwpinn_model.h5
# Epoch 27/200
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0222 - val_loss: 0.0177
#
# Epoch 00027: saving model to output/rwpinn_model.h5
# Epoch 28/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0217 - val_loss: 0.0174
#
# Epoch 00028: saving model to output/rwpinn_model.h5
# Epoch 29/200
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0215 - val_loss: 0.0173
#
# Epoch 00029: saving model to output/rwpinn_model.h5
# Epoch 30/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0211 - val_loss: 0.0170
#
# Epoch 00030: saving model to output/rwpinn_model.h5
# Epoch 31/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0208 - val_loss: 0.0169
#
# Epoch 00031: saving model to output/rwpinn_model.h5
# Epoch 32/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0207 - val_loss: 0.0167
#
# Epoch 00032: saving model to output/rwpinn_model.h5
# Epoch 33/200
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0204 - val_loss: 0.0165
#
# Epoch 00033: saving model to output/rwpinn_model.h5
# Epoch 34/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0202 - val_loss: 0.0165
#
# Epoch 00034: saving model to output/rwpinn_model.h5
# Epoch 35/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0201 - val_loss: 0.0163
#
# Epoch 00035: saving model to output/rwpinn_model.h5
# Epoch 36/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0198 - val_loss: 0.0161
#
# Epoch 00036: saving model to output/rwpinn_model.h5
# Epoch 37/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0196 - val_loss: 0.0160
#
# Epoch 00037: saving model to output/rwpinn_model.h5
# Epoch 38/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0195 - val_loss: 0.0157
#
# Epoch 00038: saving model to output/rwpinn_model.h5
# Epoch 39/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0193 - val_loss: 0.0157
#
# Epoch 00039: saving model to output/rwpinn_model.h5
# Epoch 40/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0191 - val_loss: 0.0155
#
# Epoch 00040: saving model to output/rwpinn_model.h5
# Epoch 41/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0186 - val_loss: 0.0156
#
# Epoch 00041: saving model to output/rwpinn_model.h5
# Epoch 42/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0188 - val_loss: 0.0151
#
# Epoch 00042: saving model to output/rwpinn_model.h5
# Epoch 43/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0184 - val_loss: 0.0150
#
# Epoch 00043: saving model to output/rwpinn_model.h5
# Epoch 44/200
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0184 - val_loss: 0.0148
#
# Epoch 00044: saving model to output/rwpinn_model.h5
# Epoch 45/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0183 - val_loss: 0.0147
#
# Epoch 00045: saving model to output/rwpinn_model.h5
# Epoch 46/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0180 - val_loss: 0.0147
#
# Epoch 00046: saving model to output/rwpinn_model.h5
# Epoch 47/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0179 - val_loss: 0.0145
#
# Epoch 00047: saving model to output/rwpinn_model.h5
# Epoch 48/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0177 - val_loss: 0.0145
#
# Epoch 00048: saving model to output/rwpinn_model.h5
# Epoch 49/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0177 - val_loss: 0.0144
#
# Epoch 00049: saving model to output/rwpinn_model.h5
# Epoch 50/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0175 - val_loss: 0.0143
#
# Epoch 00050: saving model to output/rwpinn_model.h5
# Epoch 51/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0175 - val_loss: 0.0142
#
# Epoch 00051: saving model to output/rwpinn_model.h5
# Epoch 52/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0172 - val_loss: 0.0141
#
# Epoch 00052: saving model to output/rwpinn_model.h5
# Epoch 53/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0171 - val_loss: 0.0140
#
# Epoch 00053: saving model to output/rwpinn_model.h5
# Epoch 54/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0170 - val_loss: 0.0137
#
# Epoch 00054: saving model to output/rwpinn_model.h5
# Epoch 55/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0169 - val_loss: 0.0138
#
# Epoch 00055: saving model to output/rwpinn_model.h5
# Epoch 56/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0167 - val_loss: 0.0136
#
# Epoch 00056: saving model to output/rwpinn_model.h5
# Epoch 57/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0166 - val_loss: 0.0137
#
# Epoch 00057: saving model to output/rwpinn_model.h5
# Epoch 58/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0165 - val_loss: 0.0136
#
# Epoch 00058: saving model to output/rwpinn_model.h5
# Epoch 59/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0165 - val_loss: 0.0137
#
# Epoch 00059: saving model to output/rwpinn_model.h5
# Epoch 60/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0166 - val_loss: 0.0133
#
# Epoch 00060: saving model to output/rwpinn_model.h5
# Epoch 61/200
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0163 - val_loss: 0.0133
#
# Epoch 00061: saving model to output/rwpinn_model.h5
# Epoch 62/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0161 - val_loss: 0.0134
#
# Epoch 00062: saving model to output/rwpinn_model.h5
# Epoch 63/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0163 - val_loss: 0.0132
#
# Epoch 00063: saving model to output/rwpinn_model.h5
# Epoch 64/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0162 - val_loss: 0.0132
#
# Epoch 00064: saving model to output/rwpinn_model.h5
# Epoch 65/200
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0160 - val_loss: 0.0131
#
# Epoch 00065: saving model to output/rwpinn_model.h5
# Epoch 66/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0158 - val_loss: 0.0130
#
# Epoch 00066: saving model to output/rwpinn_model.h5
# Epoch 67/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0158 - val_loss: 0.0128
#
# Epoch 00067: saving model to output/rwpinn_model.h5
# Epoch 68/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0156 - val_loss: 0.0130
#
# Epoch 00068: saving model to output/rwpinn_model.h5
# Epoch 69/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0156 - val_loss: 0.0128
#
# Epoch 00069: saving model to output/rwpinn_model.h5
# Epoch 70/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0156 - val_loss: 0.0128
#
# Epoch 00070: saving model to output/rwpinn_model.h5
# Epoch 71/200
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0156 - val_loss: 0.0126
#
# Epoch 00071: saving model to output/rwpinn_model.h5
# Epoch 72/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0154 - val_loss: 0.0126
#
# Epoch 00072: saving model to output/rwpinn_model.h5
# Epoch 73/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0153 - val_loss: 0.0126
#
# Epoch 00073: saving model to output/rwpinn_model.h5
# Epoch 74/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0152 - val_loss: 0.0125
#
# Epoch 00074: saving model to output/rwpinn_model.h5
# Epoch 75/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0151 - val_loss: 0.0124
#
# Epoch 00075: saving model to output/rwpinn_model.h5
# Epoch 76/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0151 - val_loss: 0.0125
#
# Epoch 00076: saving model to output/rwpinn_model.h5
# Epoch 77/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0150 - val_loss: 0.0123
#
# Epoch 00077: saving model to output/rwpinn_model.h5
# Epoch 78/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0149 - val_loss: 0.0123
#
# Epoch 00078: saving model to output/rwpinn_model.h5
# Epoch 79/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0148 - val_loss: 0.0123
#
# Epoch 00079: saving model to output/rwpinn_model.h5
# Epoch 80/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0148 - val_loss: 0.0123
#
# Epoch 00080: saving model to output/rwpinn_model.h5
# Epoch 81/200
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0148 - val_loss: 0.0122
#
# Epoch 00081: saving model to output/rwpinn_model.h5
# Epoch 82/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0147 - val_loss: 0.0123
#
# Epoch 00082: saving model to output/rwpinn_model.h5
# Epoch 83/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0149 - val_loss: 0.0121
#
# Epoch 00083: saving model to output/rwpinn_model.h5
# Epoch 84/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0148 - val_loss: 0.0120
#
# Epoch 00084: saving model to output/rwpinn_model.h5
# Epoch 85/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0146 - val_loss: 0.0120
#
# Epoch 00085: saving model to output/rwpinn_model.h5
# Epoch 86/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0146 - val_loss: 0.0119
#
# Epoch 00086: saving model to output/rwpinn_model.h5
# Epoch 87/200
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0144 - val_loss: 0.0119
#
# Epoch 00087: saving model to output/rwpinn_model.h5
# Epoch 88/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0144 - val_loss: 0.0119
#
# Epoch 00088: saving model to output/rwpinn_model.h5
# Epoch 89/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0144 - val_loss: 0.0118
#
# Epoch 00089: saving model to output/rwpinn_model.h5
# Epoch 90/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0143 - val_loss: 0.0118
#
# Epoch 00090: saving model to output/rwpinn_model.h5
# Epoch 91/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0142 - val_loss: 0.0118
#
# Epoch 00091: saving model to output/rwpinn_model.h5
# Epoch 92/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0143 - val_loss: 0.0116
#
# Epoch 00092: saving model to output/rwpinn_model.h5
# Epoch 93/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0142 - val_loss: 0.0118
#
# Epoch 00093: saving model to output/rwpinn_model.h5
# Epoch 94/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0143 - val_loss: 0.0116
#
# Epoch 00094: saving model to output/rwpinn_model.h5
# Epoch 95/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0141 - val_loss: 0.0116
#
# Epoch 00095: saving model to output/rwpinn_model.h5
# Epoch 96/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0141 - val_loss: 0.0116
#
# Epoch 00096: saving model to output/rwpinn_model.h5
# Epoch 97/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0139 - val_loss: 0.0118
#
# Epoch 00097: saving model to output/rwpinn_model.h5
# Epoch 98/200
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0140 - val_loss: 0.0116
#
# Epoch 00098: saving model to output/rwpinn_model.h5
# Epoch 99/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0140 - val_loss: 0.0115
#
# Epoch 00099: saving model to output/rwpinn_model.h5
# Epoch 100/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0139 - val_loss: 0.0116
#
# Epoch 00100: saving model to output/rwpinn_model.h5
# Epoch 101/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0139 - val_loss: 0.0114
#
# Epoch 00101: saving model to output/rwpinn_model.h5
# Epoch 102/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0137 - val_loss: 0.0116
#
# Epoch 00102: saving model to output/rwpinn_model.h5
# Epoch 103/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0138 - val_loss: 0.0118
#
# Epoch 00103: saving model to output/rwpinn_model.h5
# Epoch 104/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0138 - val_loss: 0.0115
#
# Epoch 00104: saving model to output/rwpinn_model.h5
# Epoch 105/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0136 - val_loss: 0.0113
#
# Epoch 00105: saving model to output/rwpinn_model.h5
# Epoch 106/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0136 - val_loss: 0.0114
#
# Epoch 00106: saving model to output/rwpinn_model.h5
# Epoch 107/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0137 - val_loss: 0.0114
#
# Epoch 00107: saving model to output/rwpinn_model.h5
# Epoch 108/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0136 - val_loss: 0.0112
#
# Epoch 00108: saving model to output/rwpinn_model.h5
# Epoch 109/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0134 - val_loss: 0.0112
#
# Epoch 00109: saving model to output/rwpinn_model.h5
# Epoch 110/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0134 - val_loss: 0.0112
#
# Epoch 00110: saving model to output/rwpinn_model.h5
# Epoch 111/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0134 - val_loss: 0.0111
#
# Epoch 00111: saving model to output/rwpinn_model.h5
# Epoch 112/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0134 - val_loss: 0.0111
#
# Epoch 00112: saving model to output/rwpinn_model.h5
# Epoch 113/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0134 - val_loss: 0.0112
#
# Epoch 00113: saving model to output/rwpinn_model.h5
# Epoch 114/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0133 - val_loss: 0.0111
#
# Epoch 00114: saving model to output/rwpinn_model.h5
# Epoch 115/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0133 - val_loss: 0.0111
#
# Epoch 00115: saving model to output/rwpinn_model.h5
# Epoch 116/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0133 - val_loss: 0.0110
#
# Epoch 00116: saving model to output/rwpinn_model.h5
# Epoch 117/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0132 - val_loss: 0.0111
#
# Epoch 00117: saving model to output/rwpinn_model.h5
# Epoch 118/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0132 - val_loss: 0.0110
#
# Epoch 00118: saving model to output/rwpinn_model.h5
# Epoch 119/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0132 - val_loss: 0.0112
#
# Epoch 00119: saving model to output/rwpinn_model.h5
# Epoch 120/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0133 - val_loss: 0.0116
#
# Epoch 00120: saving model to output/rwpinn_model.h5
# Epoch 121/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0133 - val_loss: 0.0109
#
# Epoch 00121: saving model to output/rwpinn_model.h5
# Epoch 122/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0132 - val_loss: 0.0110
#
# Epoch 00122: saving model to output/rwpinn_model.h5
# Epoch 123/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0131 - val_loss: 0.0107
#
# Epoch 00123: saving model to output/rwpinn_model.h5
# Epoch 124/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0130 - val_loss: 0.0107
#
# Epoch 00124: saving model to output/rwpinn_model.h5
# Epoch 125/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0130 - val_loss: 0.0108
#
# Epoch 00125: saving model to output/rwpinn_model.h5
# Epoch 126/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0130 - val_loss: 0.0108
#
# Epoch 00126: saving model to output/rwpinn_model.h5
# Epoch 127/200
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0130 - val_loss: 0.0108
#
# Epoch 00127: saving model to output/rwpinn_model.h5
# Epoch 128/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0128 - val_loss: 0.0108
#
# Epoch 00128: saving model to output/rwpinn_model.h5
# Epoch 129/200
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0128 - val_loss: 0.0107
#
# Epoch 00129: saving model to output/rwpinn_model.h5
# Epoch 130/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0127 - val_loss: 0.0107
#
# Epoch 00130: saving model to output/rwpinn_model.h5
# Epoch 131/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0127 - val_loss: 0.0107
#
# Epoch 00131: saving model to output/rwpinn_model.h5
# Epoch 132/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0128 - val_loss: 0.0107
#
# Epoch 00132: saving model to output/rwpinn_model.h5
# Epoch 133/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0128 - val_loss: 0.0110
#
# Epoch 00133: saving model to output/rwpinn_model.h5
# Epoch 134/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0127 - val_loss: 0.0107
#
# Epoch 00134: saving model to output/rwpinn_model.h5
# Epoch 135/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0127 - val_loss: 0.0107
#
# Epoch 00135: saving model to output/rwpinn_model.h5
# Epoch 136/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0129 - val_loss: 0.0105
#
# Epoch 00136: saving model to output/rwpinn_model.h5
# Epoch 137/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0127 - val_loss: 0.0106
#
# Epoch 00137: saving model to output/rwpinn_model.h5
# Epoch 138/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0128 - val_loss: 0.0107
#
# Epoch 00138: saving model to output/rwpinn_model.h5
# Epoch 139/200
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0126 - val_loss: 0.0106
#
# Epoch 00139: saving model to output/rwpinn_model.h5
# Epoch 140/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0127 - val_loss: 0.0107
#
# Epoch 00140: saving model to output/rwpinn_model.h5
# Epoch 141/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0127 - val_loss: 0.0105
#
# Epoch 00141: saving model to output/rwpinn_model.h5
# Epoch 142/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0125 - val_loss: 0.0104
#
# Epoch 00142: saving model to output/rwpinn_model.h5
# Epoch 143/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0125 - val_loss: 0.0106
#
# Epoch 00143: saving model to output/rwpinn_model.h5
# Epoch 144/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0126 - val_loss: 0.0105
#
# Epoch 00144: saving model to output/rwpinn_model.h5
# Epoch 145/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0124 - val_loss: 0.0105
#
# Epoch 00145: saving model to output/rwpinn_model.h5
# Epoch 146/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0125 - val_loss: 0.0105
#
# Epoch 00146: saving model to output/rwpinn_model.h5
# Epoch 147/200
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0124 - val_loss: 0.0105
#
# Epoch 00147: saving model to output/rwpinn_model.h5
# Epoch 148/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0124 - val_loss: 0.0104
#
# Epoch 00148: saving model to output/rwpinn_model.h5
# Epoch 149/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0123 - val_loss: 0.0106
#
# Epoch 00149: saving model to output/rwpinn_model.h5
# Epoch 150/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0125 - val_loss: 0.0103
#
# Epoch 00150: saving model to output/rwpinn_model.h5
# Epoch 151/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0122 - val_loss: 0.0104
#
# Epoch 00151: saving model to output/rwpinn_model.h5
# Epoch 152/200
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0124 - val_loss: 0.0103
#
# Epoch 00152: saving model to output/rwpinn_model.h5
# Epoch 153/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0122 - val_loss: 0.0104
#
# Epoch 00153: saving model to output/rwpinn_model.h5
# Epoch 154/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0123 - val_loss: 0.0103
#
# Epoch 00154: saving model to output/rwpinn_model.h5
# Epoch 155/200
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0122 - val_loss: 0.0102
#
# Epoch 00155: saving model to output/rwpinn_model.h5
# Epoch 156/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0123 - val_loss: 0.0103
#
# Epoch 00156: saving model to output/rwpinn_model.h5
# Epoch 157/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0122 - val_loss: 0.0102
#
# Epoch 00157: saving model to output/rwpinn_model.h5
# Epoch 158/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0122 - val_loss: 0.0102
#
# Epoch 00158: saving model to output/rwpinn_model.h5
# Epoch 159/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0122 - val_loss: 0.0102
#
# Epoch 00159: saving model to output/rwpinn_model.h5
# Epoch 160/200
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0121 - val_loss: 0.0102
#
# Epoch 00160: saving model to output/rwpinn_model.h5
# Epoch 161/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0121 - val_loss: 0.0103
#
# Epoch 00161: saving model to output/rwpinn_model.h5
# Epoch 162/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0121 - val_loss: 0.0101
#
# Epoch 00162: saving model to output/rwpinn_model.h5
# Epoch 163/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0121 - val_loss: 0.0101
#
# Epoch 00163: saving model to output/rwpinn_model.h5
# Epoch 164/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0122 - val_loss: 0.0102
#
# Epoch 00164: saving model to output/rwpinn_model.h5
# Epoch 165/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0122 - val_loss: 0.0102
#
# Epoch 00165: saving model to output/rwpinn_model.h5
# Epoch 166/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0122 - val_loss: 0.0102
#
# Epoch 00166: saving model to output/rwpinn_model.h5
# Epoch 167/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0121 - val_loss: 0.0101
#
# Epoch 00167: saving model to output/rwpinn_model.h5
# Epoch 168/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0119 - val_loss: 0.0100
#
# Epoch 00168: saving model to output/rwpinn_model.h5
# Epoch 169/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0119 - val_loss: 0.0102
#
# Epoch 00169: saving model to output/rwpinn_model.h5
# Epoch 170/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0120 - val_loss: 0.0100
#
# Epoch 00170: saving model to output/rwpinn_model.h5
# Epoch 171/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0119 - val_loss: 0.0102
#
# Epoch 00171: saving model to output/rwpinn_model.h5
# Epoch 172/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0120 - val_loss: 0.0101
#
# Epoch 00172: saving model to output/rwpinn_model.h5
# Epoch 173/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0119 - val_loss: 0.0099
#
# Epoch 00173: saving model to output/rwpinn_model.h5
# Epoch 174/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0119 - val_loss: 0.0102
#
# Epoch 00174: saving model to output/rwpinn_model.h5
# Epoch 175/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0119 - val_loss: 0.0099
#
# Epoch 00175: saving model to output/rwpinn_model.h5
# Epoch 176/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0118 - val_loss: 0.0101
#
# Epoch 00176: saving model to output/rwpinn_model.h5
# Epoch 177/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0119 - val_loss: 0.0101
#
# Epoch 00177: saving model to output/rwpinn_model.h5
# Epoch 178/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0120 - val_loss: 0.0100
#
# Epoch 00178: saving model to output/rwpinn_model.h5
# Epoch 179/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0119 - val_loss: 0.0100
#
# Epoch 00179: saving model to output/rwpinn_model.h5
# Epoch 180/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0117 - val_loss: 0.0099
#
# Epoch 00180: saving model to output/rwpinn_model.h5
# Epoch 181/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0118 - val_loss: 0.0100
#
# Epoch 00181: saving model to output/rwpinn_model.h5
# Epoch 182/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0118 - val_loss: 0.0099
#
# Epoch 00182: saving model to output/rwpinn_model.h5
# Epoch 183/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0118 - val_loss: 0.0099
#
# Epoch 00183: saving model to output/rwpinn_model.h5
# Epoch 184/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0117 - val_loss: 0.0098
#
# Epoch 00184: saving model to output/rwpinn_model.h5
# Epoch 185/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0116 - val_loss: 0.0100
#
# Epoch 00185: saving model to output/rwpinn_model.h5
# Epoch 186/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0118 - val_loss: 0.0098
#
# Epoch 00186: saving model to output/rwpinn_model.h5
# Epoch 187/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0116 - val_loss: 0.0099
#
# Epoch 00187: saving model to output/rwpinn_model.h5
# Epoch 188/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0117 - val_loss: 0.0098
#
# Epoch 00188: saving model to output/rwpinn_model.h5
# Epoch 189/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0116 - val_loss: 0.0100
#
# Epoch 00189: saving model to output/rwpinn_model.h5
# Epoch 190/200
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0117 - val_loss: 0.0098
#
# Epoch 00190: saving model to output/rwpinn_model.h5
# Epoch 191/200
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0116 - val_loss: 0.0096
#
# Epoch 00191: saving model to output/rwpinn_model.h5
# Epoch 192/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0115 - val_loss: 0.0098
#
# Epoch 00192: saving model to output/rwpinn_model.h5
# Epoch 193/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0116 - val_loss: 0.0098
#
# Epoch 00193: saving model to output/rwpinn_model.h5
# Epoch 194/200
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0116 - val_loss: 0.0098
#
# Epoch 00194: saving model to output/rwpinn_model.h5
# Epoch 195/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0115 - val_loss: 0.0099
#
# Epoch 00195: saving model to output/rwpinn_model.h5
# Epoch 196/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0115 - val_loss: 0.0097
#
# Epoch 00196: saving model to output/rwpinn_model.h5
# Epoch 197/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0116 - val_loss: 0.0097
#
# Epoch 00197: saving model to output/rwpinn_model.h5
# Epoch 198/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0116 - val_loss: 0.0098
#
# Epoch 00198: saving model to output/rwpinn_model.h5
# Epoch 199/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0116 - val_loss: 0.0097
#
# Epoch 00199: saving model to output/rwpinn_model.h5
# Epoch 200/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0115 - val_loss: 0.0097
#
# Epoch 00200: saving model to output/rwpinn_model.h5

# %%
regr_lr.coef_, regr_lr.intercept_
# Out:
# (array([[-11.39919887]]), array([10.10783853]))

# %%
rw_pinn.get_layer('linear1d').get_weights()
# Out:
# [array([[-10.12274]], dtype=float32), array([[9.876765]], dtype=float32)]

# %% [markdown]
# # eval

# %%
# load the saved model
rw_pinn.load_weights('output/rwpinn_model.h5')

# %%
# Testing and evaluating the model
Batch_size = 128
preds = rw_pinn.evaluate(X_test_final, Y_test, batch_size=Batch_size, verbose=0, sample_weight=None)
print("Loss = " + str(preds))
# Out:
# Loss = 0.009441004134714603

# %%
# Plotting the learning curve 
plt.plot(history.history['loss']/np.max(history.history['loss']));
plt.plot(history.history['val_loss']/np.max(history.history['val_loss']));

#plt.title('Learning curve')
plt.ylabel('Normalized Loss');
plt.xlabel('Epochs');
plt.legend(['Training loss', 'Validation loss'], loc='upper right');

# plt.ylim([0.05, 0.2]);

# %% [markdown]
# ## encoder

# %%
## Only the Encoder part
rw_pinn_encoder = Model(inputs=input_final, outputs=encoded)

# %%
encoder_output_trainset = rw_pinn_encoder.predict(X_train_final)
phi_trainset_pred = ((encoder_output_trainset+1)/2) * (phi_max - phi_min) + phi_min

# %%
encoder_output_testset = rw_pinn_encoder.predict(X_test_final)
phi_testset_pred = ((encoder_output_testset+1)/2) * (phi_max - phi_min) + phi_min

# %%
phi_trainset_true = Y_train[:, 246:246+199] * (phi_max - phi_min) + phi_min
phi_testset_true = Y_test[:, 246:246+199] * (phi_max - phi_min) + phi_min

# %%
phi_train_error = mean_squared_error(phi_trainset_true,phi_trainset_pred)
phi_test_error = mean_squared_error(phi_testset_true,phi_testset_pred)

print('Porosity Train error:',phi_train_error)
print('Porosity Test error:',phi_test_error)
# Out:
# Porosity Train error: 0.005746768836813336
# Porosity Test error: 0.005732047472369043

# %%
# sample_number = 400
sample_number = np.random.choice(phi_trainset_true.shape[0], size = 1)[0]

plt.plot(phi_trainset_true[sample_number, :], depth, color = "black", label = 'true');
plt.plot(phi_trainset_pred[sample_number, :], depth, label = 'predicted');
plt.xlabel("Porosity [V/V]");
plt.ylabel("Depth [meters]");
plt.legend();
plt.gca().invert_yaxis();
sample_number
# Out:
# 598

# %%
# sample_number = 400
sample_number = np.random.choice(phi_testset_true.shape[0], size = 1)[0]

plt.plot(phi_testset_true[sample_number, :], depth, color = "black", label = 'true');
plt.plot(phi_testset_pred[sample_number, :], depth, label = 'predicted');
plt.xlabel("Porosity [V/V]");
plt.ylabel("Depth [meters]");
plt.legend();
plt.gca().invert_yaxis();
sample_number
# Out:
# 427

# %% [markdown]
# ## decoder

# %%
## Only the Decoder part
# rw_pinn_decoder = Model(inputs=encoded, outputs=seis_for_final)

# %%
# decoder_output_trainset = rw_pinn_decoder.predict(encoder_output_trainset)
# seis_output_trainset = decoder_output_trainset[:,0:246]

# decoder_output_testset = rw_pinn_decoder.predict(encoder_output_testset)
# seis_output_testset = decoder_output_testset[:,0:246]

# %%
decoder_output_trainset = rw_pinn.predict(X_train_final)
seis_output_trainset = decoder_output_trainset[:,0:246]

decoder_output_testset = rw_pinn.predict(X_test_final)
seis_output_testset = decoder_output_testset[:,0:246]

# %%
# sample_number = 400
sample_number = np.random.choice(phi_testset_true.shape[0], size = 1)[0]

plt.plot(np.squeeze(X_train_final[sample_number,:,:]), time_upscaled, color = "black", label='true');
plt.plot(seis_output_trainset[sample_number,:], time_upscaled, label='predicted');
plt.gca().invert_yaxis();
plt.legend();
plt.ylabel('Time');
sample_number
# Out:
# 336

# %%
# sample_number = 400
sample_number = np.random.choice(phi_testset_true.shape[0], size = 1)[0]

plt.plot(np.squeeze(X_test_final[sample_number,:,:]), time_upscaled, color = "black", label='true');
plt.plot(seis_output_testset[sample_number,:], time_upscaled, label='predicted');
plt.gca().invert_yaxis();
plt.legend();
plt.ylabel('Time');
sample_number
# Out:
# 245

# %% [markdown]
# ## final

# %%
encoder_output_set = rw_pinn_encoder.predict(np.expand_dims(np.expand_dims(seis_normalized, axis=1),axis=3))
phi_set_pred = ((encoder_output_set+1)/2) * (phi_max - phi_min) + phi_min

decoder_output_set = rw_pinn.predict(np.expand_dims(np.expand_dims(seis_normalized, axis=1),axis=3))
seis_output_set=decoder_output_set[:,0:246]

# %%
phi_error = np.sqrt(mean_squared_error(phi_true, phi_set_pred))
print('Porosity RMS error:', phi_error)
# Out:
# Porosity RMS error: 0.07578802388308205

# %%
phi_train_error = np.sqrt(mean_squared_error(phi_trainset_true, phi_trainset_pred))
phi_test_error = np.sqrt(mean_squared_error(phi_testset_true, phi_testset_pred))

print('Porosity Trainset RMS error:', phi_train_error)
print('Porosity Testset RMS error:', phi_test_error)
# Out:
# Porosity Trainset RMS error: 0.07580744578742471
# Porosity Testset RMS error: 0.0757102864369766

# %%
seis_error = np.sqrt(mean_squared_error(seis, seis_output_set*(np.max(seis)-np.min(seis))+ np.min(seis)))
seis_error_train = np.sqrt(mean_squared_error(np.squeeze(X_train_final)*(np.max(seis)-np.min(seis))+ np.min(seis), seis_output_trainset*(np.max(seis)-np.min(seis))+ np.min(seis)))
seis_error_test = np.sqrt(mean_squared_error(np.squeeze(X_test_final)*(np.max(seis)-np.min(seis))+ np.min(seis), seis_output_testset*(np.max(seis)-np.min(seis))+ np.min(seis)))

print('Seismic RMS error:', seis_error)
print('Seismic Train RMS error:', seis_error_train)
print('Seismic Test RMS error:', seis_error_test)
# Out:
# Seismic RMS error: 0.0044017044322621065
# Seismic Train RMS error: 0.00421626518196709
# Seismic Test RMS error: 0.005076163946047279

# %%
fig, axs = plt.subplots(1, 4, sharey=True)

i = np.random.choice(X_train_final.shape[0], size = 1)[0]
# axs[0].plot(np.squeeze(X_train_final[34,:,:]),time_upscaled,'k',linewidth=2,label='True');
# axs[0].plot(seis_output_trainset[34,:],time_upscaled,'o',alpha=0.2,label='Predicted');
axs[0].plot(np.squeeze(X_train_final[i,:,:]),time_upscaled,'k',linewidth=2,label='True');
axs[0].plot(seis_output_trainset[i,:],time_upscaled,'o',alpha=0.2,label='Predicted');
axs[0].set_yticks([0,0.05,0.1,0.15]);
axs[0].set_xticks([0,0.5,1]);
axs[0].set_xticklabels(('0','0.5','1'));
axs[0].set_title('Train-set {}'.format(i));

i = np.random.choice(X_train_final.shape[0], size = 1)[0]
# axs[1].plot(np.squeeze(X_train_final[64,:,:]),time_upscaled,'k',linewidth=2);
# axs[1].plot(seis_output_trainset[64,:],time_upscaled,'o',alpha=0.2);
axs[1].plot(np.squeeze(X_train_final[i,:,:]),time_upscaled,'k',linewidth=2);
axs[1].plot(seis_output_trainset[i,:],time_upscaled,'o',alpha=0.2);
axs[1].set_xticks([0,0.5,1]);
axs[1].set_xticklabels(('0','0.5','1'));
axs[1].set_title('Train-set {}'.format(i));

j = np.random.choice(X_test_final.shape[0], size = 1)[0]
# axs[2].plot(np.squeeze(X_test_final[21,:,:]),time_upscaled,'k',linewidth=2);
# axs[2].plot(seis_output_testset[21,:],time_upscaled,'o',alpha=0.2);
axs[2].plot(np.squeeze(X_test_final[21,:,:]),time_upscaled,'k',linewidth=2);
axs[2].plot(seis_output_testset[21,:],time_upscaled,'o',alpha=0.2);
axs[2].set_xticks([0,0.5,1]);
axs[2].set_xticklabels(('0','0.5','1'));
axs[2].set_title('Test-set {}'.format(j));

j = np.random.choice(X_test_final.shape[0], size = 1)[0]
# axs[3].plot(np.squeeze(X_test_final[26,:,:]),time_upscaled,'k',linewidth=2);
# axs[3].plot(seis_output_testset[26,:],time_upscaled,'o',alpha=0.2);
axs[3].plot(np.squeeze(X_test_final[j,:,:]),time_upscaled,'k',linewidth=2);
axs[3].plot(seis_output_testset[j,:],time_upscaled,'o',alpha=0.2);
axs[3].set_xticks([0,0.5,1]);
axs[3].set_xticklabels(('0','0.5','1'));
axs[3].set_title('Test-set {}'.format(j));

fig.supxlabel('Normalized amplitude');
fig.supylabel('Time(s)');
handles, labels = axs[0].get_legend_handles_labels()
fig.legend(handles, labels, loc='lower left');

plt.gca().invert_yaxis();

# %%
fig, axs = plt.subplots(1, 4, sharey=True);

i = np.random.choice(phi_trainset_true.shape[0], size = 1)[0]
# axs[0].plot(phi_trainset_true[34, :], depth,'k',label='True');
# axs[0].plot(phi_trainset_pred[34, :], depth,label='Predicted');
axs[0].plot(phi_trainset_true[i, :], depth,'k',label='True');
axs[0].plot(phi_trainset_pred[i, :], depth,label='Predicted');
axs[0].set_yticks([0,50,100,150,200]);
axs[0].set_xticks([0.2,0.3]);
axs[0].set_title('Train-set {}'.format(i));

i = np.random.choice(phi_trainset_true.shape[0], size = 1)[0]
# axs[1].plot(phi_trainset_true[64, :], depth,'k');
# axs[1].plot(phi_trainset_pred[64, :], depth);
axs[1].plot(phi_trainset_true[i, :], depth,'k');
axs[1].plot(phi_trainset_pred[i, :], depth);
axs[1].set_xticks([0.2,0.3]);
axs[1].set_title('Train-set {}'.format(i));

j = np.random.choice(phi_testset_true.shape[0], size = 1)[0]
# axs[2].plot(phi_testset_true[21, :], depth,'k');
# axs[2].plot(phi_testset_pred[21, :], depth);
axs[2].plot(phi_testset_true[j, :], depth,'k');
axs[2].plot(phi_testset_pred[j, :], depth);
axs[2].set_xticks([0.2,0.3]);
axs[2].set_title('Test-set {}'.format(j));

j = np.random.choice(phi_testset_true.shape[0], size = 1)[0]
# axs[3].plot(phi_testset_true[26, :], depth,'k');
# axs[3].plot(phi_testset_pred[26, :], depth);
axs[3].plot(phi_testset_true[j, :], depth,'k');
axs[3].plot(phi_testset_pred[j, :], depth);
axs[3].set_xticks([0.2,0.3]);
axs[3].set_title('Test-set {}'.format(j));

fig.supxlabel('Porosity(V/V)');
fig.supylabel('Depth(m)');
handles, labels = axs[0].get_legend_handles_labels()
fig.legend(handles, labels, loc='lower left');

plt.gca().invert_yaxis();
